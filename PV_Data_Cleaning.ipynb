# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

df = pd.read_csv("./data-source/data.csv")
df.head(5)
# Out:
#       location   latitude  longitude        date      time temperature  \
# 0  Camden East  44.335385 -76.833312  2017-01-01   9:00:00       -1.52
# 1  Camden East  44.335385 -76.833312  2017-01-01  10:00:00       -1.13
# 2  Camden East  44.335385 -76.833312  2017-01-01  11:00:00       -0.32
# 3  Camden East  44.335385 -76.833312  2017-01-01  12:00:00       -0.12
# 4  Camden East  44.335385 -76.833312  2017-01-01  13:00:00        0.88
#
#   uv_index wind_speed cloud_cover precip_intensity
# 0        0       7.77        0.75                0
# 1        1          7        0.75                0
# 2        1          7        0.75                0
# 3        1       4.67           1                0
# 4        1       8.69           1                0

# %% [markdown]
# PART 1 - CLEAN DATA

# %%
#examine datatypes
df.dtypes
# Out:
# location             object
# latitude            float64
# longitude           float64
# date                 object
# time                 object
# temperature          object
# uv_index             object
# wind_speed           object
# cloud_cover          object
# precip_intensity     object
# dtype: object

# %%
#convert data types 
cols = ['temperature','uv_index', 'wind_speed', 'cloud_cover', 'precip_intensity']
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
df['date'] = df['date'].astype('datetime64[ns]')
#df.set_index('date',inplace=True)

# %%
#derive two new columns
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df.dtypes
# Out:
# location                    object
# latitude                   float64
# longitude                  float64
# date                datetime64[ns]
# time                        object
# temperature                float64
# uv_index                   float64
# wind_speed                 float64
# cloud_cover                float64
# precip_intensity           float64
# month                        int64
# year                         int64
# dtype: object

# %%
#how abt % of missing values per column
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# location             0.000000
# latitude             0.000000
# longitude            0.000000
# date                 0.000000
# time                 0.000000
# temperature          0.283342
# uv_index            18.123649
# wind_speed           0.639008
# cloud_cover         18.489526
# precip_intensity    16.611643
# month                0.000000
# year                 0.000000
# dtype: float64

# %%
#NaN stats
df.isnull().sum()
# Out:
# location                0
# latitude                0
# longitude               0
# date                    0
# time                    0
# temperature           333
# uv_index            21300
# wind_speed            751
# cloud_cover         21730
# precip_intensity    19523
# month                   0
# year                    0
# dtype: int64

# %%
#fill missing NaNs using ffill followed by bfill. 
#ffill to replace by taking most recent non-NaN value before within the same date
#bfill in case first hour of day is missing (i.e 9 am) in that case take the most recent valid value after but within the same date

missing_vals = ['temperature','wind_speed','uv_index','cloud_cover','precip_intensity']

for i in missing_vals:
    df[i] = df.groupby(['location','date'])[i].ffill()
    df[i] = df.groupby(['location','date'])[i].bfill()

# %%
#recheck Nan stats, some reduction
df.isnull().sum()
# Out:
# location                0
# latitude                0
# longitude               0
# date                    0
# time                    0
# temperature             0
# uv_index            18247
# wind_speed            450
# cloud_cover         21234
# precip_intensity    18532
# month                   0
# year                    0
# dtype: int64

# %%
#replace remaining Nans for WHOLE DAY with randomly selected value specific to that month, year

#get NaN indices
cols = ['wind_speed','uv_index','cloud_cover','precip_intensity']
nan_index = []

for i in cols:
    nan_index.append(df[i].index[df[i].apply(np.isnan)].tolist())
    
i = -1

for c in cols:
    i += 1
    for j in nan_index[i]:
        month_period = df.loc[df.index == j,'month'].item()
        year_period = df.loc[df.index == j,'year'].item()
        df[c] = np.where(df.index == j
                         ,df.loc[(df.month == month_period) & (df.year == year_period)][c].dropna().sample(replace=True).item()
                         ,df[c])
        
        



#Option 1 - fill remaining Nans with mean for that month, year
#df['wind_speed'] = df.groupby(['location', df.date.dt.year,df.date.dt.month])['wind_speed'].transform(lambda x: x.fillna(x.mean()))

# %%
#recheck Nans
df.isnull().sum()
# Out:
# location            0
# latitude            0
# longitude           0
# date                0
# time                0
# temperature         0
# uv_index            0
# wind_speed          0
# cloud_cover         0
# precip_intensity    0
# month               0
# year                0
# dtype: int64

# %%
#group data by avg

dg =df.groupby(['location',df.date.dt.year,df.date.dt.month],as_index=False).mean()

dg.head(20)
# Out:
#        location   latitude  longitude  temperature  uv_index  wind_speed  \
# 0   Camden East  44.335385 -76.833312    -1.745878  0.645161   12.099462
# 1   Camden East  44.335385 -76.833312    -0.831468  1.317460   12.770714
# 2   Camden East  44.335385 -76.833312    -1.411075  2.397849   14.337885
# 3   Camden East  44.335385 -76.833312     9.895111  3.551852   13.354222
# 4   Camden East  44.335385 -76.833312    13.821756  4.000000   11.579247
# 5   Camden East  44.335385 -76.833312    19.797889  4.640741   12.168704
# 6   Camden East  44.335385 -76.833312    22.409355  4.476703   10.311828
# 7   Camden East  44.335385 -76.833312    21.786846  3.956989   10.368746
# 8   Camden East  44.335385 -76.833312    20.453519  2.988889    8.847667
# 9   Camden East  44.335385 -76.833312    14.774982  1.663082   13.917634
# 10  Camden East  44.335385 -76.833312     3.969593  0.788889   12.595889
# 11  Camden East  44.335385 -76.833312    -5.768853  0.555556   11.302509
# 12  Camden East  44.335385 -76.833312    -6.178280  0.652330   12.033226
# 13  Camden East  44.335385 -76.833312    -1.083929  1.301587   11.942579
# 14  Camden East  44.335385 -76.833312     0.770430  2.473118   11.882796
# 15  Camden East  44.335385 -76.833312     4.927407  3.500000   14.407333
# 16  Camden East  44.335385 -76.833312    17.079606  4.559140   12.812151
# 17  Camden East  44.335385 -76.833312    19.301778  4.707407   15.424593
# 18  Camden East  44.335385 -76.833312    24.475484  5.046595   16.844552
# 19  Camden East  44.335385 -76.833312    23.746774  3.698925   14.822545
#
#     cloud_cover  precip_intensity  month  year
# 0      0.803369          0.034537      1  2017
# 1      0.776032          0.042927      2  2017
# 2      0.731756          0.069929      3  2017
# 3      0.753333          0.169060      4  2017
# 4      0.815986          0.213444      5  2017
# 5      0.706000          0.142989      6  2017
# 6      0.692007          0.127911      7  2017
# 7      0.656918          0.050216      8  2017
# 8      0.543704          0.037614      9  2017
# 9      0.689570          0.195141     10  2017
# 10     0.806148          0.104491     11  2017
# 11     0.719928          0.032276     12  2017
# 12     0.847670          0.023599      1  2018
# 13     0.819325          0.284338      2  2018
# 14     0.706093          0.050138      3  2018
# 15     0.770741          0.144320      4  2018
# 16     0.631039          0.164803      5  2018
# 17     0.671296          0.385870      6  2018
# 18     0.520000          0.388027      7  2018
# 19     0.727025          0.291141      8  2018

# %% [markdown]
# PART 2 - MERGE PV POTENTIALS WITH CLEANED DATA

# %%
dp = pd.read_csv("./data-source/municip_potentiel-potential.csv", encoding = "ISO-8859-1")
dp.head(5)
# Out:
#                     Unnamed: 0    Unnamed: 1 Unnamed: 2  \
# 0                     Province  Municipality      month
# 1                     province  municipalité       mois
# 2  Nova Scotia/Nouvelle-Écosse   St. Peter's    January
# 3  Nova Scotia/Nouvelle-Écosse   St. Peter's   February
# 4  Nova Scotia/Nouvelle-Écosse   St. Peter's      March
#
#      PV potential / Potentiel PV (kWh/kWp)  \
# 0         South-facing vertical (tilt=90°)
# 1  vertical orienté vers le sud (inc.=90°)
# 2                                       56
# 3                                       71
# 4                                       83
#
#   PV potential / Potentiel PV (kWh/kWp).1  \
# 0              South-facing tilt=latitude
# 1     orienté vers le sud (inc.=latitude)
# 2                                      55
# 3                                      75
# 4                                     102
#
#     PV potential / Potentiel PV (kWh/kWp).2  \
# 0                 South-facing tilt=lat+15°
# 1  orienté vers le sud (inc.=latitude +15°)
# 2                                        58
# 3                                        77
# 4                                        99
#
#     PV potential / Potentiel PV (kWh/kWp).3
# 0                 South-facing tilt=lat-15°
# 1  orienté vers le sud (inc.=latitude -15°)
# 2                                        50
# 3                                        69
# 4                                        99

# %%
#get Ontario  data only
dp = dp[dp['Unnamed: 0']=='Ontario'].reset_index(drop=True)

# %%
dp = dp.rename(index=str, columns={"Unnamed: 0": "Province", "Unnamed: 1": "location", "Unnamed: 2": "month",\
                                  "PV potential / Potentiel PV (kWh/kWp)": "PVpot tilt=90",\
                                  "PV potential / Potentiel PV (kWh/kWp).1": "PVpot tilt=lat",\
                                  "PV potential / Potentiel PV (kWh/kWp).2": "PVpot tilt=lat+15",\
                                  "PV potential / Potentiel PV (kWh/kWp).3": "PVpot tilt=lat-15"})

#drop Annual based rows. 
dp = dp[dp.month != 'Annual']

dp.dtypes
# Out:
# Province             object
# location             object
# month                object
# PVpot tilt=90        object
# PVpot tilt=lat       object
# PVpot tilt=lat+15    object
# PVpot tilt=lat-15    object
# dtype: object

# %%
#change data type of PV potential colums to float
columns = ['PVpot tilt=90','PVpot tilt=lat','PVpot tilt=lat+15','PVpot tilt=lat-15']
dp[columns] = dp[columns].apply(pd.to_numeric, downcast = 'float',errors='coerce')

dp.dtypes
# Out:
# Province              object
# location              object
# month                 object
# PVpot tilt=90        float32
# PVpot tilt=lat       float32
# PVpot tilt=lat+15    float32
# PVpot tilt=lat-15    float32
# dtype: object

# %%
#derive new columns
dp['AvgPVPotential'] = (dp['PVpot tilt=90'] + dp['PVpot tilt=lat'] + dp['PVpot tilt=lat+15'] + dp['PVpot tilt=lat-15'])/4

#PVPotential to be lat+15 for Jan-Mar,Oct-Dec, otherwise lat-15 as per optimal tilts
def get_PVPotential(row):
    latplus15_months = ['January','February','March','October','November','December']
    if row['month'] in latplus15_months:
        return row['PVpot tilt=lat+15']
    else:
        return row['PVpot tilt=lat-15']
    
dp['PVPotential'] = dp.apply (lambda row: get_PVPotential(row), axis=1)

# %%
dp.head(20)
# Out:
#    Province     location      month  PVpot tilt=90  PVpot tilt=lat  \
# 0   Ontario  Quinte West    January           75.0            73.0
# 1   Ontario  Quinte West   February           84.0            88.0
# 2   Ontario  Quinte West      March           92.0           115.0
# 3   Ontario  Quinte West      April           70.0           113.0
# 4   Ontario  Quinte West        May           65.0           123.0
# 5   Ontario  Quinte West       June           60.0           123.0
# 6   Ontario  Quinte West       July           65.0           131.0
# 7   Ontario  Quinte West     August           70.0           121.0
# 8   Ontario  Quinte West  September           72.0           102.0
# 9   Ontario  Quinte West    October           75.0            89.0
# 10  Ontario  Quinte West   November           54.0            56.0
# 11  Ontario  Quinte West   December           60.0            58.0
# 13  Ontario  North Perth    January           58.0            57.0
# 14  Ontario  North Perth   February           76.0            81.0
# 15  Ontario  North Perth      March           94.0           115.0
# 16  Ontario  North Perth      April           77.0           119.0
# 17  Ontario  North Perth        May           66.0           124.0
# 18  Ontario  North Perth       June           59.0           122.0
# 19  Ontario  North Perth       July           63.0           126.0
# 20  Ontario  North Perth     August           68.0           118.0
#
#     PVpot tilt=lat+15  PVpot tilt=lat-15  AvgPVPotential  PVPotential
# 0                78.0               64.0           72.50         78.0
# 1                91.0               81.0           86.00         91.0
# 2               113.0              111.0          107.75        113.0
# 3               103.0              116.0          100.50        116.0
# 4               108.0              133.0          107.25        133.0
# 5               105.0              135.0          105.75        135.0
# 6               113.0              144.0          113.25        144.0
# 7               109.0              128.0          107.00        128.0
# 8                97.0              102.0           93.25        102.0
# 9                89.0               84.0           84.25         89.0
# 10               59.0               51.0           55.00         59.0
# 11               62.0               51.0           57.75         62.0
# 13               60.0               52.0           56.75         60.0
# 14               84.0               75.0           79.00         84.0
# 15              114.0              112.0          108.75        114.0
# 16              110.0              123.0          107.25        123.0
# 17              109.0              134.0          108.25        134.0
# 18              104.0              135.0          105.00        135.0
# 19              109.0              138.0          109.00        138.0
# 20              106.0              125.0          104.25        125.0

# %%
#convert month int to month names
import calendar

dg['month'] = dg['month'].apply(lambda x: calendar.month_name[x])

# %%
dg.head(10)
# Out:
#       location   latitude  longitude  temperature  uv_index  wind_speed  \
# 0  Camden East  44.335385 -76.833312    -1.745878  0.645161   12.099462
# 1  Camden East  44.335385 -76.833312    -0.831468  1.317460   12.770714
# 2  Camden East  44.335385 -76.833312    -1.411075  2.397849   14.337885
# 3  Camden East  44.335385 -76.833312     9.895111  3.551852   13.354222
# 4  Camden East  44.335385 -76.833312    13.821756  4.000000   11.579247
# 5  Camden East  44.335385 -76.833312    19.797889  4.640741   12.168704
# 6  Camden East  44.335385 -76.833312    22.409355  4.476703   10.311828
# 7  Camden East  44.335385 -76.833312    21.786846  3.956989   10.368746
# 8  Camden East  44.335385 -76.833312    20.453519  2.988889    8.847667
# 9  Camden East  44.335385 -76.833312    14.774982  1.663082   13.917634
#
#    cloud_cover  precip_intensity      month  year
# 0     0.803369          0.034537    January  2017
# 1     0.776032          0.042927   February  2017
# 2     0.731756          0.069929      March  2017
# 3     0.753333          0.169060      April  2017
# 4     0.815986          0.213444        May  2017
# 5     0.706000          0.142989       June  2017
# 6     0.692007          0.127911       July  2017
# 7     0.656918          0.050216     August  2017
# 8     0.543704          0.037614  September  2017
# 9     0.689570          0.195141    October  2017

# %%
cleaned = pd.merge(dp, dg,  how='inner', on=['location', 'month'])

#can add more columns, if required...
cols = ['temperature','uv_index', 'wind_speed', 'cloud_cover','precip_intensity','PVPotential']
cleaned = cleaned[cols]

# %%
#print final cleaned data to use in regression, ML etc

cleaned.head(10)
# Out:
#    temperature  uv_index  wind_speed  cloud_cover  precip_intensity  \
# 0    -3.783835  0.602151   10.693978     0.772294          0.018808
# 1    -8.174803  0.616487   11.618423     0.805591          0.044539
# 2    -3.085040  1.277778   11.819484     0.736667          0.032070
# 3    -2.404643  1.246032   11.607937     0.734405          0.055358
# 4    -3.388925  2.415771   14.013226     0.646953          0.022958
# 5     0.121720  2.408602   12.841720     0.681541          0.040613
# 6     9.884741  3.503704   14.127111     0.725593          0.054833
# 7     5.224741  3.488889   14.517370     0.746963          0.083654
# 8    14.774552  4.086022   13.390358     0.771613          0.054051
# 9    18.657312  4.713262   12.589749     0.557814          0.054665
#
#    PVPotential
# 0         84.0
# 1         84.0
# 2        101.0
# 3        101.0
# 4        123.0
# 5        123.0
# 6        116.0
# 7        116.0
# 8        129.0
# 9        129.0
